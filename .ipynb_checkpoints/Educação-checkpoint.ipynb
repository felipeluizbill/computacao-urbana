# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("educacao.csv" , sep =";", decimal =",", encoding = "UTF-8")

# %%
prv = df.loc[(df['TIPO'].str.contains('PRIVADO' , na=False))]
prv
# Out:
#                                 NOME  \
# 3                     EDUCARE, C E I
# 4     CRISTAO DE CURITIBA, C-EI EF M
# 8            LAR BOM PASTOR, E-EI EF
# 10                  TRAMPOLIM, C E I
# 14         LUSA- LUZ DO SABER, C E I
# ...                              ...
# 1406     PINTANDO O SETE, PRE ESC-EI
# 1423  TURMINHA PEQUENOS ANJOS, C E I
# 1428    PONTO DE PARTIDA BABY, C E I
# 1429   PONTO DE PARTIDA JUNIOR, E-EF
# 1434   INOVACAO DO SABER JUNIOR, CEI
#
#                                           LOGRADOURO            BAIRRO  \
# 3                                     RUA MEXICO 580         BACACHERI
# 4                              RUA DAVID BODZIAK 207         CACHOEIRA
# 8                              RUA IRMA ANATOLIA 421       BARREIRINHA
# 10                            RUA HUMBERTO LEVIS 387       BARREIRINHA
# 14                         RUA CARMELITA CAVASSIN 50       BARREIRINHA
# ...                                              ...               ...
# ...

# %%
pub = df.loc[(df['TIPO'].str.contains('PÚBLICA' , na=False))]
pub
# Out:
#                                     NOME                         LOGRADOURO  \
# 0            ROMARIO MARTINS, E M CEI-EF              RUA DAVID BODZIAK 828
# 1                  VILA LEONICE, C M E I              RUA DAVID BODZIAK 828
# 2           MARIA AP B HARTMANN, C M E I               RUA OVIDIO GARCEZ 59
# 5       TANIRA REGINA SCHMIDT, E M-EI EF             RUA VICTOR KOTOVIS 162
# 6           GETULIO VARGAS, C E C-M-EF M           RUA EMILIA MARIA UBA 325
# ...                                  ...                                ...
# 1431  GERDT GUENTHER HATSCHBACH, C M E I            RUA LUCAS CARVALHO 1436
# 1432               RIO BONITO, E M-EI EF            RUA LUCAS CARVALHO 1486
# 1433        MILTON LUIZ PEREIRA, C M E I  RUA URIEL NOGUEIRA DOS SANTOS 700
# 1435        JOANA RAKSA, E M PROFA-EI EF   RUA FRANCISCA BERALDE PAOLINI 99
# 1436                    CAXIMBA, C M E I  RUA EST DEL BRUNO DE ALMEIDA 8059
#
#                 BAIRRO     TIPO   LATITUDE  LONGITUDE
# ...

# %%
m = folium.Map(location=[df.LATITUDE.mean(), df.LONGITUDE.mean()], zoom_start=13, tiles='OpenStreet Map')

def addToMap(df , c): 
    X = np.array(df) 
    plt.scatter(X[:,0], X[:,1], alpha=0.2, s=50) 
    for _, row in df.iterrows(): 
        folium.CircleMarker( location=[row.LATITUDE, row.LONGITUDE], 
                            radius=2, 
                            color=c, 
                            fill=True, 
                            fill_colour='c', 
                            opacity = 0.5, 
                            fill_opacity=0.5
    ).add_to(m)
        
addToMap(prv , '#1787FE') 
addToMap(pub , '#8B0000') 
m.save("educacao.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
dados = pd.read_csv("educacao.csv" , sep =";", decimal =",", encoding = "UTF-8")
dados = dados[['LATITUDE' , 'LONGITUDE']]
dados
# Out:
#        LATITUDE  LONGITUDE
# 0    -25.352993 -49.255426
# 1    -25.352993 -49.255426
# 2    -25.353024 -49.262721
# 3    -25.353534 -49.202061
# 4    -25.354130 -49.261162
# ...         ...        ...
# 1432 -25.594988 -49.325458
# 1433 -25.598266 -49.330351
# 1434 -25.609002 -49.277214
# 1435 -25.619044 -49.348521
# 1436 -25.619883 -49.347799
#
# [1437 rows x 2 columns]

# %%
dados = np.array(dados)

def dbscan(X, eps, min_samples):
    ss = StandardScaler()
    X = ss.fit_transform(X)
    db = DBSCAN(eps=eps, min_samples=min_samples)
    db.fit(X)
    y_pred = db.fit_predict(X)
    plt.scatter(X[:,0], X[:,1],c=y_pred, cmap='Paired')
    plt.title("DBSCAN")

dbscan(dados , .1 , 1)
